# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import os
import time
import numpy as np
import matplotlib.pyplot as plt
import torch
import cv2
from PIL import Image
from ultralytics import YOLO

# Define the input and output directories
inpDir = ''  # location where input data is stored
outDir = ''  # location to store outputs
subDir = ''  # location of the images
modelDir = ''
altName = 'yolo'

RANDOM_STATE = 24  # for initialization ----- REMEMBER: to remove at the time of promotion to production
EPOCHS = 100  # number of cycles to run
THRESHOLD = 0.6  # Updated threshold for object detection

# Set parameters for decoration of plots
params = {'legend.fontsize': 'large',
          'figure.figsize': (15, 12),
          'axes.labelsize': 'x-large',
          'axes.titlesize': 'x-large',
          'xtick.labelsize': 'large',
          'ytick.labelsize': 'large',
          }

CMAP = plt.cm.brg

plt.rcParams.update(params)  # update rcParams

# Helper Functions
COCO_INSTANCE_CATEGORY_NAMES = [
    '__background__', 'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus',
    'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'N/A', 'stop sign',
    'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow',
    'elephant', 'bear', 'zebra', 'giraffe', 'N/A', 'backpack', 'umbrella', 'N/A', 'N/A',
    'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball',
    'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket',
    'bottle', 'N/A', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl',
    'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza',
    'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'N/A', 'dining table',
    'N/A', 'N/A', 'toilet', 'N/A', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone',
    'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'N/A', 'book',
    'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush'
]

# Create different colors for each class.
COLORS = np.random.uniform(0, 255, size=(len(COCO_INSTANCE_CATEGORY_NAMES), 3))

# Load YOLOv8s model (small variant for better accuracy)
def get_yolo_model(device='cpu'):
    model = YOLO('yolov8s.pt')  # Load YOLOv8 Small model (for better accuracy)
    model.eval().to(device)
    return model

# YOLOv8 Object Detection Prediction
def predict_yolo(image, model, device, threshold=0.5):
    results = model(image)  # Run inference
    result = results[0]  # Access the first element (the result for the first image)

    # Access bounding boxes from the result
    boxes = result.boxes  # This is a 'Boxes' object
    pred_boxes = boxes.xywh.cpu().numpy()  # Get [x_center, y_center, width, height]

    # Confidence scores
    pred_conf = boxes.conf.cpu().numpy()  # Confidence scores

    # Class labels (numeric labels)
    pred_labels = boxes.cls.cpu().numpy().astype(int)  # Class labels, ensure they're integers

    # Get class names
    pred_classes = result.names  # Class names dictionary

    # Filter out predictions below the threshold
    valid_idx = pred_conf >= threshold
    boxes_filtered = pred_boxes[valid_idx].astype(np.int32)
    labels_filtered = pred_labels[valid_idx]

    return boxes_filtered, [pred_classes[int(label)] for label in labels_filtered], labels_filtered


# Draw bounding boxes on the image
def draw_boxes_yolo(boxes, classes, labels, image):
    lw = max(round(sum(image.shape) / 2 * 0.001), 2)  # Line width for boxes
    tf = max(lw - 1, 2)  # Text thickness
    
    for i, box in enumerate(boxes):
        color = COLORS[int(labels[i])]  # Convert label to integer for indexing COLORS
        
        # Draw bounding box
        cv2.rectangle(
            img=image,
            pt1=(int(box[0] - box[2] / 2), int(box[1] - box[3] / 2)),
            pt2=(int(box[0] + box[2] / 2), int(box[1] + box[3] / 2)),
            color=color[::-1],  # Convert RGB to BGR for OpenCV
            thickness=lw
        )
        
        # Add class label
        cv2.putText(
            img=image,
            text=classes[i],
            org=(int(box[0] - box[2] / 2), int(box[1] - box[3] / 2) - 5),
            fontFace=cv2.FONT_HERSHEY_SIMPLEX,
            fontScale=lw / 2,
            color=color[::-1],
            thickness=tf,
            lineType=cv2.LINE_AA
        )
    
    return image

# Load the video and process it
def process_video_yolo(video_path, model, device, threshold=0.5):
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print('Error while trying to read video. Please check path again')
        return
    
    frame_width = int(cap.get(3))
    frame_height = int(cap.get(4))
    save_name = f"{video_path.split('/')[-1].split('.')[0]}_yolo_{''.join(str(threshold).split('.'))}"
    out = cv2.VideoWriter(os.path.join(outDir, f"{save_name}.mp4"),
                          cv2.VideoWriter_fourcc(*'mp4v'), 30,
                          (frame_width, frame_height))
    
    frame_count = 0
    total_fps = 0
    
    while cap.isOpened():
        ret, frame = cap.read()
        if ret:
            frame_copy = frame.copy()
            frame_copy = cv2.cvtColor(frame_copy, cv2.COLOR_BGR2RGB)
            
            # Resize the frame to improve detection
            frame_resized = cv2.resize(frame_copy, (1280, 720))  # Use higher resolution
            
            # Start timer
            start_time = time.time()
            
            # Get YOLO predictions
            boxes, classes, labels = predict_yolo(frame_resized, model, device, threshold)
            
            # Scale the boxes back to the original frame dimensions
            scale_x = frame_width / 1280
            scale_y = frame_height / 720
            boxes = boxes * [scale_x, scale_y, scale_x, scale_y]  # Rescale bounding boxes

            # Draw boxes on the original frame
            frame_copy = draw_boxes_yolo(boxes, classes, labels, frame_copy)
            
            # Calculate FPS
            end_time = time.time()
            fps = 1 / (end_time - start_time)
            total_fps += fps
            frame_count += 1
            
            # Add FPS on frame
            cv2.putText(
                img=frame_copy,
                text=f"{fps:.3f} FPS",
                org=(15, 30),
                fontFace=cv2.FONT_HERSHEY_SIMPLEX,
                fontScale=1,
                color=(0, 255, 0),
                thickness=2,
                lineType=cv2.LINE_AA
            )
            
            # Write processed frame to video output
            out.write(frame_copy)
            
            # Display the frame
            cv2.imshow('YOLO Video', frame_copy)
            
            # Exit if 'q' is pressed
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break
        else:
            break
    
    cap.release()
    out.release()
    cv2.destroyAllWindows()
    
    # Print average FPS
    avg_fps = total_fps / frame_count
    print(f"Average FPS: {avg_fps:.3f}")

# Main function to run the video processing
def main():
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    print(f"Using {device} device for inference")
    
    # Load YOLOv8s model
    model = get_yolo_model(device)
    
    # Process video
    vidName = 'VID_20240320164919_F (online-video-cutter.com).mp4'  # Specify your video file path here
    vidFilePath = os.path.join(inpDir, subDir, vidName)
    process_video_yolo(vidFilePath, model, device, threshold=THRESHOLD)

if __name__ == "__main__":
    main()
# Out:
# Using cuda device for inference
#
# 0: 384x640 15 persons, 1 motorcycle, 2 trucks, 61.8ms
# Speed: 2.8ms preprocess, 61.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 4 trucks, 19.3ms
# Speed: 0.0ms preprocess, 19.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 2 trucks, 12.1ms
# Speed: 1.2ms preprocess, 12.1ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 3 trucks, 14.8ms
# Speed: 2.2ms preprocess, 14.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 2 trucks, 1 umbrella, 7.4ms
# Speed: 1.0ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 2 trucks, 14.0ms
# Speed: 0.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 car, 3 trucks, 11.1ms
# Speed: 2.3ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 3 trucks, 19.3ms
# Speed: 0.0ms preprocess, 19.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 4 trucks, 16.7ms
# Speed: 0.0ms preprocess, 16.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 4 trucks, 8.5ms
# Speed: 1.9ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 3 trucks, 12.3ms
# Speed: 1.7ms preprocess, 12.3ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 4 trucks, 11.3ms
# Speed: 3.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 2 trucks, 11.6ms
# Speed: 1.0ms preprocess, 11.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 motorcycle, 4 trucks, 11.2ms
# Speed: 2.0ms preprocess, 11.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 bicycle, 3 trucks, 10.9ms
# Speed: 2.0ms preprocess, 10.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 2 trucks, 1 handbag, 11.8ms
# Speed: 1.0ms preprocess, 11.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 2 trucks, 11.2ms
# Speed: 2.0ms preprocess, 11.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 2 trucks, 1 horse, 11.3ms
# Speed: 2.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 2 trucks, 10.6ms
# Speed: 2.0ms preprocess, 10.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 bicycle, 2 trucks, 11.3ms
# Speed: 2.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 2 trucks, 15.9ms
# Speed: 0.7ms preprocess, 15.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 bicycle, 1 truck, 11.7ms
# Speed: 2.0ms preprocess, 11.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 bicycle, 1 truck, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 bicycle, 1 truck, 14.7ms
# Speed: 0.0ms preprocess, 14.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 bicycle, 1 truck, 13.2ms
# Speed: 0.0ms preprocess, 13.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 bicycle, 1 truck, 11.9ms
# Speed: 2.9ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 bicycle, 2 trucks, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 bicycle, 1 truck, 1 horse, 11.5ms
# Speed: 1.8ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 bicycle, 1 car, 1 truck, 11.3ms
# Speed: 2.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 bicycle, 1 truck, 16.2ms
# Speed: 4.0ms preprocess, 16.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 2 bicycles, 1 car, 1 truck, 17.6ms
# Speed: 1.5ms preprocess, 17.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 2 bicycles, 1 car, 1 motorcycle, 1 truck, 1 horse, 16.7ms
# Speed: 2.0ms preprocess, 16.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 bicycle, 1 car, 1 truck, 1 horse, 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 2 bicycles, 1 motorcycle, 1 truck, 17.9ms
# Speed: 2.0ms preprocess, 17.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 3 bicycles, 1 truck, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 3 bicycles, 1 car, 1 truck, 1 elephant, 17.5ms
# Speed: 1.0ms preprocess, 17.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 3 bicycles, 1 truck, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 2 bicycles, 2 cars, 1 bus, 1 truck, 1 umbrella, 17.3ms
# Speed: 2.0ms preprocess, 17.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 2 bicycles, 1 car, 1 truck, 1 umbrella, 17.1ms
# Speed: 2.0ms preprocess, 17.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 4 bicycles, 2 cars, 1 motorcycle, 1 truck, 1 umbrella, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 4 bicycles, 1 car, 1 truck, 1 umbrella, 18.2ms
# Speed: 1.0ms preprocess, 18.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 2 bicycles, 1 car, 1 motorcycle, 1 truck, 1 umbrella, 17.3ms
# Speed: 2.0ms preprocess, 17.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 2 bicycles, 1 car, 1 motorcycle, 1 truck, 1 horse, 1 umbrella, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 2 bicycles, 1 car, 2 motorcycles, 2 trucks, 18.1ms
# Speed: 1.3ms preprocess, 18.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 2 bicycles, 1 car, 2 motorcycles, 1 truck, 1 surfboard, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 2 bicycles, 1 car, 1 truck, 1 surfboard, 18.5ms
# Speed: 2.0ms preprocess, 18.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 bicycle, 1 car, 1 motorcycle, 2 trucks, 18.7ms
# Speed: 2.0ms preprocess, 18.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 bicycle, 2 cars, 1 motorcycle, 2 trucks, 1 surfboard, 18.5ms
# Speed: 2.0ms preprocess, 18.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 bicycle, 2 cars, 1 motorcycle, 2 trucks, 18.6ms
# Speed: 2.0ms preprocess, 18.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 1 motorcycle, 1 truck, 18.2ms
# Speed: 2.0ms preprocess, 18.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 1 motorcycle, 2 trucks, 1 backpack, 1 umbrella, 19.0ms
# Speed: 2.0ms preprocess, 19.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 car, 1 motorcycle, 2 trucks, 1 backpack, 18.7ms
# Speed: 2.0ms preprocess, 18.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 2 bicycles, 1 car, 2 motorcycles, 1 truck, 1 horse, 1 backpack, 19.3ms
# Speed: 2.0ms preprocess, 19.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 bicycle, 1 car, 1 motorcycle, 1 truck, 1 horse, 1 backpack, 19.7ms
# Speed: 2.0ms preprocess, 19.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 2 bicycles, 1 car, 1 truck, 1 backpack, 1 umbrella, 19.6ms
# Speed: 1.0ms preprocess, 19.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 2 bicycles, 1 car, 1 truck, 19.4ms
# Speed: 2.0ms preprocess, 19.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 4 bicycles, 1 car, 1 truck, 1 backpack, 19.5ms
# Speed: 1.0ms preprocess, 19.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 3 bicycles, 1 car, 1 truck, 1 backpack, 19.2ms
# Speed: 2.0ms preprocess, 19.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 3 bicycles, 1 car, 1 truck, 1 backpack, 19.9ms
# Speed: 2.3ms preprocess, 19.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 2 bicycles, 1 car, 1 truck, 1 backpack, 20.3ms
# Speed: 1.1ms preprocess, 20.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bicycle, 1 car, 1 motorcycle, 1 truck, 1 backpack, 19.9ms
# Speed: 2.0ms preprocess, 19.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 bicycle, 1 car, 2 motorcycles, 1 truck, 1 backpack, 20.1ms
# Speed: 1.3ms preprocess, 20.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 bicycle, 1 car, 1 motorcycle, 1 truck, 1 backpack, 19.9ms
# Speed: 2.0ms preprocess, 19.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bicycle, 1 car, 2 motorcycles, 2 trucks, 1 backpack, 20.4ms
# Speed: 2.0ms preprocess, 20.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 bicycle, 1 car, 1 motorcycle, 2 trucks, 1 backpack, 20.7ms
# Speed: 1.0ms preprocess, 20.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 bicycle, 1 car, 1 motorcycle, 1 truck, 1 backpack, 20.1ms
# Speed: 2.0ms preprocess, 20.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 bicycle, 1 car, 2 motorcycles, 3 trucks, 1 backpack, 19.8ms
# Speed: 2.0ms preprocess, 19.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 car, 2 motorcycles, 1 truck, 1 horse, 1 backpack, 20.7ms
# Speed: 2.0ms preprocess, 20.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 car, 3 motorcycles, 2 trucks, 1 horse, 1 backpack, 20.9ms
# Speed: 2.0ms preprocess, 20.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 car, 2 motorcycles, 1 truck, 1 horse, 1 backpack, 20.9ms
# Speed: 1.0ms preprocess, 20.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 car, 3 motorcycles, 1 bus, 1 truck, 1 backpack, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 car, 1 motorcycle, 2 trucks, 1 backpack, 20.9ms
# Speed: 2.3ms preprocess, 20.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 car, 1 motorcycle, 1 backpack, 20.8ms
# Speed: 3.1ms preprocess, 20.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 car, 1 motorcycle, 1 bus, 1 truck, 1 backpack, 21.3ms
# Speed: 1.0ms preprocess, 21.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 car, 2 motorcycles, 1 truck, 1 backpack, 20.6ms
# Speed: 2.0ms preprocess, 20.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 car, 2 motorcycles, 1 backpack, 20.8ms
# Speed: 2.0ms preprocess, 20.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 1 motorcycle, 1 truck, 2 horses, 1 backpack, 21.0ms
# Speed: 2.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bicycle, 1 car, 1 motorcycle, 1 truck, 1 backpack, 21.7ms
# Speed: 2.1ms preprocess, 21.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 car, 1 motorcycle, 1 truck, 1 backpack, 21.6ms
# Speed: 2.0ms preprocess, 21.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 bicycle, 1 car, 1 motorcycle, 1 bus, 1 backpack, 21.0ms
# Speed: 2.0ms preprocess, 21.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bicycle, 1 car, 4 motorcycles, 1 horse, 1 backpack, 1 umbrella, 21.2ms
# Speed: 1.7ms preprocess, 21.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bicycle, 1 car, 5 motorcycles, 1 bus, 1 cow, 1 backpack, 21.0ms
# Speed: 2.0ms preprocess, 21.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bicycle, 1 car, 3 motorcycles, 1 bus, 1 backpack, 21.9ms
# Speed: 2.0ms preprocess, 21.9ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 bicycle, 1 car, 2 motorcycles, 1 bus, 1 truck, 1 backpack, 21.9ms
# Speed: 2.0ms preprocess, 21.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 bicycle, 1 car, 2 motorcycles, 1 bus, 1 truck, 1 backpack, 22.9ms
# Speed: 2.0ms preprocess, 22.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 bicycle, 1 car, 2 motorcycles, 1 truck, 1 backpack, 22.7ms
# Speed: 1.4ms preprocess, 22.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 2 bicycles, 1 car, 2 motorcycles, 1 bus, 1 backpack, 1 handbag, 21.9ms
# Speed: 2.0ms preprocess, 21.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 2 bicycles, 2 motorcycles, 1 backpack, 1 handbag, 22.8ms
# Speed: 1.0ms preprocess, 22.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 3 bicycles, 1 car, 2 motorcycles, 1 backpack, 22.2ms
# Speed: 2.0ms preprocess, 22.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 3 bicycles, 1 car, 3 motorcycles, 1 truck, 1 backpack, 22.2ms
# Speed: 2.0ms preprocess, 22.2ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 2 bicycles, 3 cars, 2 motorcycles, 1 backpack, 1 handbag, 22.7ms
# Speed: 2.0ms preprocess, 22.7ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 bicycle, 2 cars, 3 motorcycles, 1 cow, 1 backpack, 1 handbag, 22.6ms
# Speed: 2.2ms preprocess, 22.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 2 bicycles, 1 car, 2 motorcycles, 1 bus, 1 truck, 1 backpack, 23.1ms
# Speed: 2.0ms preprocess, 23.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bicycle, 1 car, 3 motorcycles, 1 bus, 2 backpacks, 23.1ms
# Speed: 2.7ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 bicycle, 3 motorcycles, 1 bus, 1 truck, 1 backpack, 23.6ms
# Speed: 1.4ms preprocess, 23.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 bicycle, 1 car, 2 motorcycles, 1 bus, 1 backpack, 22.8ms
# Speed: 2.2ms preprocess, 22.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 2 bicycles, 1 car, 2 motorcycles, 1 bus, 1 truck, 1 handbag, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bicycle, 1 car, 2 motorcycles, 1 bus, 1 truck, 1 backpack, 22.9ms
# Speed: 2.0ms preprocess, 22.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 bicycle, 3 cars, 2 motorcycles, 1 bus, 23.3ms
# Speed: 3.0ms preprocess, 23.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 bicycle, 1 car, 5 motorcycles, 1 bus, 1 truck, 23.9ms
# Speed: 1.0ms preprocess, 23.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 bicycle, 4 motorcycles, 1 bus, 24.0ms
# Speed: 2.0ms preprocess, 24.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 bicycle, 5 motorcycles, 1 bus, 23.0ms
# Speed: 2.0ms preprocess, 23.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 2 bicycles, 3 motorcycles, 1 bus, 23.5ms
# Speed: 1.4ms preprocess, 23.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 2 bicycles, 5 motorcycles, 1 bus, 1 truck, 23.4ms
# Speed: 2.1ms preprocess, 23.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 2 bicycles, 5 motorcycles, 1 bus, 23.3ms
# Speed: 2.0ms preprocess, 23.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 bicycle, 4 motorcycles, 1 truck, 24.2ms
# Speed: 1.0ms preprocess, 24.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 2 bicycles, 4 motorcycles, 1 bus, 24.4ms
# Speed: 2.0ms preprocess, 24.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 bicycle, 4 motorcycles, 1 bus, 23.9ms
# Speed: 2.3ms preprocess, 23.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 bicycle, 5 motorcycles, 23.3ms
# Speed: 3.0ms preprocess, 23.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 8 motorcycles, 24.2ms
# Speed: 2.2ms preprocess, 24.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 5 motorcycles, 24.6ms
# Speed: 2.0ms preprocess, 24.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 6 motorcycles, 24.3ms
# Speed: 2.1ms preprocess, 24.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 4 motorcycles, 24.5ms
# Speed: 2.0ms preprocess, 24.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 4 motorcycles, 24.6ms
# Speed: 2.0ms preprocess, 24.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 5 motorcycles, 24.6ms
# Speed: 1.5ms preprocess, 24.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 4 motorcycles, 24.8ms
# Speed: 2.0ms preprocess, 24.8ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 bicycle, 3 motorcycles, 24.1ms
# Speed: 2.0ms preprocess, 24.1ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 bicycle, 2 motorcycles, 24.5ms
# Speed: 2.0ms preprocess, 24.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 3 motorcycles, 25.4ms
# Speed: 1.2ms preprocess, 25.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 2 motorcycles, 1 horse, 24.7ms
# Speed: 2.0ms preprocess, 24.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 5 motorcycles, 25.3ms
# Speed: 2.0ms preprocess, 25.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 5 motorcycles, 24.8ms
# Speed: 2.0ms preprocess, 24.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 4 motorcycles, 1 truck, 24.6ms
# Speed: 2.4ms preprocess, 24.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 2 motorcycles, 1 bus, 1 truck, 25.2ms
# Speed: 2.0ms preprocess, 25.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 3 motorcycles, 1 truck, 25.0ms
# Speed: 2.0ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 5 motorcycles, 1 truck, 25.6ms
# Speed: 2.0ms preprocess, 25.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 4 motorcycles, 1 truck, 25.3ms
# Speed: 1.3ms preprocess, 25.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 7 motorcycles, 25.3ms
# Speed: 2.0ms preprocess, 25.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 3 motorcycles, 1 horse, 1 backpack, 25.0ms
# Speed: 2.0ms preprocess, 25.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 4 motorcycles, 1 truck, 25.3ms
# Speed: 2.0ms preprocess, 25.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 3 motorcycles, 1 horse, 25.5ms
# Speed: 1.0ms preprocess, 25.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 4 motorcycles, 1 horse, 1 cow, 25.5ms
# Speed: 2.0ms preprocess, 25.5ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 3 motorcycles, 1 cow, 25.0ms
# Speed: 3.0ms preprocess, 25.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 4 motorcycles, 25.7ms
# Speed: 1.0ms preprocess, 25.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 4 motorcycles, 26.2ms
# Speed: 1.2ms preprocess, 26.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 3 motorcycles, 1 bus, 25.3ms
# Speed: 3.0ms preprocess, 25.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 2 bicycles, 4 motorcycles, 27.3ms
# Speed: 2.1ms preprocess, 27.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 bicycle, 4 motorcycles, 25.5ms
# Speed: 2.2ms preprocess, 25.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 4 motorcycles, 1 horse, 25.2ms
# Speed: 2.0ms preprocess, 25.2ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 4 motorcycles, 25.7ms
# Speed: 2.3ms preprocess, 25.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 3 motorcycles, 25.9ms
# Speed: 1.7ms preprocess, 25.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 4 motorcycles, 26.0ms
# Speed: 2.3ms preprocess, 26.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 4 motorcycles, 25.6ms
# Speed: 2.0ms preprocess, 25.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 bicycle, 6 motorcycles, 25.5ms
# Speed: 1.7ms preprocess, 25.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 5 motorcycles, 1 bus, 25.4ms
# Speed: 2.0ms preprocess, 25.4ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 4 motorcycles, 25.6ms
# Speed: 2.0ms preprocess, 25.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 5 motorcycles, 1 truck, 26.4ms
# Speed: 2.0ms preprocess, 26.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 car, 4 motorcycles, 26.0ms
# Speed: 2.0ms preprocess, 26.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 3 motorcycles, 1 horse, 26.2ms
# Speed: 2.3ms preprocess, 26.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 4 motorcycles, 25.6ms
# Speed: 1.7ms preprocess, 25.6ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 4 motorcycles, 25.3ms
# Speed: 2.0ms preprocess, 25.3ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 car, 6 motorcycles, 26.1ms
# Speed: 2.0ms preprocess, 26.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 car, 4 motorcycles, 26.6ms
# Speed: 1.0ms preprocess, 26.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 5 motorcycles, 26.7ms
# Speed: 2.0ms preprocess, 26.7ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 2 cars, 3 motorcycles, 27.0ms
# Speed: 1.3ms preprocess, 27.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 car, 5 motorcycles, 26.4ms
# Speed: 2.0ms preprocess, 26.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 2 cars, 5 motorcycles, 27.2ms
# Speed: 2.1ms preprocess, 27.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 car, 7 motorcycles, 26.8ms
# Speed: 2.0ms preprocess, 26.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 car, 4 motorcycles, 26.0ms
# Speed: 2.0ms preprocess, 26.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 car, 4 motorcycles, 25.8ms
# Speed: 2.3ms preprocess, 25.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 car, 7 motorcycles, 26.1ms
# Speed: 2.0ms preprocess, 26.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 car, 4 motorcycles, 26.4ms
# Speed: 1.4ms preprocess, 26.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 car, 4 motorcycles, 25.4ms
# Speed: 2.0ms preprocess, 25.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 car, 3 motorcycles, 27.2ms
# Speed: 1.3ms preprocess, 27.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 car, 4 motorcycles, 25.7ms
# Speed: 2.0ms preprocess, 25.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 car, 2 motorcycles, 2 horses, 26.5ms
# Speed: 1.7ms preprocess, 26.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 5 motorcycles, 2 trucks, 26.0ms
# Speed: 1.5ms preprocess, 26.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 car, 2 motorcycles, 3 trucks, 25.1ms
# Speed: 3.8ms preprocess, 25.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 3 motorcycles, 1 truck, 27.3ms
# Speed: 3.1ms preprocess, 27.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 3 motorcycles, 1 truck, 26.8ms
# Speed: 1.0ms preprocess, 26.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 car, 3 motorcycles, 1 truck, 26.8ms
# Speed: 2.2ms preprocess, 26.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 2 motorcycles, 2 trucks, 2 horses, 26.3ms
# Speed: 2.0ms preprocess, 26.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 bicycle, 2 motorcycles, 3 trucks, 2 horses, 25.7ms
# Speed: 2.5ms preprocess, 25.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 4 motorcycles, 2 trucks, 26.7ms
# Speed: 2.7ms preprocess, 26.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 bicycle, 5 motorcycles, 2 trucks, 25.8ms
# Speed: 2.0ms preprocess, 25.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 bicycle, 3 motorcycles, 2 trucks, 25.7ms
# Speed: 2.0ms preprocess, 25.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 bicycle, 4 motorcycles, 3 trucks, 25.6ms
# Speed: 3.2ms preprocess, 25.6ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bicycle, 2 motorcycles, 3 trucks, 26.5ms
# Speed: 2.0ms preprocess, 26.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bicycle, 5 motorcycles, 2 trucks, 25.7ms
# Speed: 2.0ms preprocess, 25.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 2 motorcycles, 3 trucks, 1 traffic light, 26.4ms
# Speed: 2.0ms preprocess, 26.4ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 bicycle, 2 motorcycles, 2 trucks, 25.3ms
# Speed: 2.3ms preprocess, 25.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 bicycle, 1 car, 2 motorcycles, 2 trucks, 25.3ms
# Speed: 2.1ms preprocess, 25.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 bicycle, 2 motorcycles, 3 trucks, 26.0ms
# Speed: 2.0ms preprocess, 26.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 bicycle, 1 car, 3 motorcycles, 3 trucks, 25.8ms
# Speed: 2.0ms preprocess, 25.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bicycle, 1 car, 4 motorcycles, 2 trucks, 25.8ms
# Speed: 2.5ms preprocess, 25.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 3 motorcycles, 2 trucks, 1 horse, 25.2ms
# Speed: 2.8ms preprocess, 25.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 bicycle, 1 car, 3 motorcycles, 2 trucks, 26.8ms
# Speed: 1.0ms preprocess, 26.8ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 2 bicycles, 3 motorcycles, 2 trucks, 1 umbrella, 25.4ms
# Speed: 2.1ms preprocess, 25.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 3 motorcycles, 2 trucks, 1 horse, 25.3ms
# Speed: 2.0ms preprocess, 25.3ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 2 bicycles, 3 motorcycles, 1 truck, 1 horse, 26.0ms
# Speed: 1.2ms preprocess, 26.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 bicycle, 2 motorcycles, 2 trucks, 1 horse, 26.4ms
# Speed: 2.0ms preprocess, 26.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 2 bicycles, 2 motorcycles, 2 trucks, 27.3ms
# Speed: 3.0ms preprocess, 27.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 2 motorcycles, 2 trucks, 2 horses, 28.9ms
# Speed: 0.0ms preprocess, 28.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 bicycle, 2 motorcycles, 1 truck, 1 horse, 1 handbag, 27.0ms
# Speed: 1.0ms preprocess, 27.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 2 motorcycles, 2 trucks, 25.9ms
# Speed: 2.0ms preprocess, 25.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 bicycle, 3 motorcycles, 3 trucks, 1 handbag, 25.6ms
# Speed: 2.0ms preprocess, 25.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 2 motorcycles, 3 trucks, 1 handbag, 26.2ms
# Speed: 4.3ms preprocess, 26.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 2 bicycles, 2 motorcycles, 3 trucks, 26.2ms
# Speed: 2.0ms preprocess, 26.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 bicycle, 2 motorcycles, 3 trucks, 25.7ms
# Speed: 2.4ms preprocess, 25.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 bicycle, 2 motorcycles, 3 trucks, 25.8ms
# Speed: 2.0ms preprocess, 25.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 2 motorcycles, 2 buss, 3 trucks, 25.7ms
# Speed: 1.0ms preprocess, 25.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 bicycle, 2 motorcycles, 3 trucks, 22.7ms
# Speed: 5.0ms preprocess, 22.7ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 2 bicycles, 2 motorcycles, 3 trucks, 24.8ms
# Speed: 2.0ms preprocess, 24.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 bicycle, 3 motorcycles, 3 trucks, 25.8ms
# Speed: 2.0ms preprocess, 25.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 bicycle, 3 motorcycles, 3 trucks, 25.3ms
# Speed: 2.0ms preprocess, 25.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 bicycle, 4 motorcycles, 3 trucks, 25.3ms
# Speed: 2.0ms preprocess, 25.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 bicycle, 2 motorcycles, 3 trucks, 25.7ms
# Speed: 1.0ms preprocess, 25.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bicycle, 4 motorcycles, 3 trucks, 25.7ms
# Speed: 1.0ms preprocess, 25.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 bicycle, 4 motorcycles, 3 trucks, 27.5ms
# Speed: 0.0ms preprocess, 27.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 3 motorcycles, 4 trucks, 25.4ms
# Speed: 1.2ms preprocess, 25.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 car, 3 motorcycles, 1 bus, 3 trucks, 25.1ms
# Speed: 2.0ms preprocess, 25.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 bicycle, 4 motorcycles, 1 bus, 4 trucks, 24.5ms
# Speed: 2.0ms preprocess, 24.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 bicycle, 3 motorcycles, 1 bus, 3 trucks, 24.8ms
# Speed: 2.0ms preprocess, 24.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bicycle, 3 motorcycles, 1 bus, 2 trucks, 28.8ms
# Speed: 0.0ms preprocess, 28.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bicycle, 5 motorcycles, 1 bus, 4 trucks, 25.4ms
# Speed: 2.0ms preprocess, 25.4ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 3 bicycles, 4 motorcycles, 1 bus, 5 trucks, 25.6ms
# Speed: 2.0ms preprocess, 25.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 bicycle, 2 motorcycles, 1 bus, 5 trucks, 26.9ms
# Speed: 0.0ms preprocess, 26.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 4 bicycles, 2 motorcycles, 4 trucks, 26.4ms
# Speed: 5.1ms preprocess, 26.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 2 bicycles, 2 motorcycles, 4 trucks, 25.9ms
# Speed: 4.1ms preprocess, 25.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 bicycle, 2 motorcycles, 3 trucks, 25.3ms
# Speed: 2.0ms preprocess, 25.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 bicycle, 2 motorcycles, 4 trucks, 23.9ms
# Speed: 2.0ms preprocess, 23.9ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bicycle, 3 motorcycles, 4 trucks, 25.5ms
# Speed: 2.8ms preprocess, 25.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 2 bicycles, 3 motorcycles, 4 trucks, 25.7ms
# Speed: 1.0ms preprocess, 25.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 2 bicycles, 2 motorcycles, 4 trucks, 25.7ms
# Speed: 2.0ms preprocess, 25.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 2 bicycles, 1 motorcycle, 3 trucks, 24.6ms
# Speed: 2.6ms preprocess, 24.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 2 bicycles, 2 motorcycles, 3 trucks, 25.2ms
# Speed: 2.0ms preprocess, 25.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 2 bicycles, 2 motorcycles, 3 trucks, 25.6ms
# Speed: 2.0ms preprocess, 25.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 2 bicycles, 2 motorcycles, 5 trucks, 24.6ms
# Speed: 2.0ms preprocess, 24.6ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 2 bicycles, 1 motorcycle, 4 trucks, 25.7ms
# Speed: 2.0ms preprocess, 25.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 2 bicycles, 2 motorcycles, 2 trucks, 25.3ms
# Speed: 2.0ms preprocess, 25.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 2 bicycles, 2 motorcycles, 2 trucks, 26.7ms
# Speed: 1.0ms preprocess, 26.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 2 bicycles, 2 motorcycles, 3 trucks, 26.7ms
# Speed: 2.0ms preprocess, 26.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 2 bicycles, 2 motorcycles, 2 trucks, 26.5ms
# Speed: 1.0ms preprocess, 26.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 2 bicycles, 2 motorcycles, 3 trucks, 25.7ms
# Speed: 3.0ms preprocess, 25.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 2 bicycles, 2 motorcycles, 2 trucks, 26.2ms
# Speed: 1.5ms preprocess, 26.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 4 bicycles, 3 motorcycles, 3 trucks, 26.7ms
# Speed: 1.0ms preprocess, 26.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 bicycle, 2 motorcycles, 3 trucks, 26.5ms
# Speed: 1.0ms preprocess, 26.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bicycle, 2 motorcycles, 3 trucks, 26.0ms
# Speed: 2.0ms preprocess, 26.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 bicycle, 1 motorcycle, 3 trucks, 25.6ms
# Speed: 0.2ms preprocess, 25.6ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 motorcycle, 1 bus, 2 trucks, 26.1ms
# Speed: 2.0ms preprocess, 26.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 bicycle, 2 motorcycles, 1 bus, 2 trucks, 26.1ms
# Speed: 2.0ms preprocess, 26.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 bicycle, 4 motorcycles, 3 trucks, 26.6ms
# Speed: 1.3ms preprocess, 26.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 5 motorcycles, 3 trucks, 26.6ms
# Speed: 0.0ms preprocess, 26.6ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 3 motorcycles, 3 trucks, 26.7ms
# Speed: 2.0ms preprocess, 26.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 motorcycle, 3 trucks, 1 horse, 24.7ms
# Speed: 1.0ms preprocess, 24.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 3 motorcycles, 3 trucks, 27.2ms
# Speed: 1.9ms preprocess, 27.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 4 motorcycles, 1 bus, 3 trucks, 1 horse, 25.4ms
# Speed: 2.0ms preprocess, 25.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 3 motorcycles, 1 bus, 4 trucks, 26.4ms
# Speed: 3.6ms preprocess, 26.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 3 motorcycles, 3 trucks, 25.9ms
# Speed: 2.0ms preprocess, 25.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 4 motorcycles, 3 trucks, 25.9ms
# Speed: 1.7ms preprocess, 25.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 5 motorcycles, 3 trucks, 29.5ms
# Speed: 0.0ms preprocess, 29.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 6 motorcycles, 3 trucks, 26.3ms
# Speed: 2.0ms preprocess, 26.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 bicycle, 4 motorcycles, 1 bus, 3 trucks, 1 umbrella, 26.3ms
# Speed: 2.0ms preprocess, 26.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 6 motorcycles, 1 bus, 2 trucks, 25.3ms
# Speed: 3.0ms preprocess, 25.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 6 motorcycles, 1 bus, 2 trucks, 26.4ms
# Speed: 3.5ms preprocess, 26.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 5 motorcycles, 1 bus, 2 trucks, 26.1ms
# Speed: 2.0ms preprocess, 26.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 3 motorcycles, 1 bus, 2 trucks, 26.1ms
# Speed: 2.0ms preprocess, 26.1ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 4 motorcycles, 1 bus, 2 trucks, 26.6ms
# Speed: 1.0ms preprocess, 26.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 3 motorcycles, 1 bus, 2 trucks, 1 chair, 24.2ms
# Speed: 2.0ms preprocess, 24.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 2 motorcycles, 1 bus, 2 trucks, 1 chair, 26.8ms
# Speed: 1.0ms preprocess, 26.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 2 motorcycles, 1 bus, 2 trucks, 25.9ms
# Speed: 2.0ms preprocess, 25.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 4 motorcycles, 4 trucks, 26.9ms
# Speed: 1.0ms preprocess, 26.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 bicycle, 3 motorcycles, 2 trucks, 26.3ms
# Speed: 1.0ms preprocess, 26.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 4 motorcycles, 3 trucks, 25.7ms
# Speed: 1.8ms preprocess, 25.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 6 motorcycles, 3 trucks, 25.9ms
# Speed: 2.0ms preprocess, 25.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 4 motorcycles, 3 trucks, 25.8ms
# Speed: 2.2ms preprocess, 25.8ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 3 motorcycles, 3 trucks, 25.4ms
# Speed: 1.6ms preprocess, 25.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 3 motorcycles, 1 bus, 3 trucks, 26.3ms
# Speed: 1.0ms preprocess, 26.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 3 motorcycles, 1 bus, 2 trucks, 26.3ms
# Speed: 1.0ms preprocess, 26.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 4 motorcycles, 1 bus, 3 trucks, 25.9ms
# Speed: 2.0ms preprocess, 25.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 4 motorcycles, 1 bus, 2 trucks, 28.0ms
# Speed: 0.0ms preprocess, 28.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 5 motorcycles, 1 bus, 3 trucks, 26.8ms
# Speed: 2.0ms preprocess, 26.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 3 motorcycles, 3 trucks, 26.3ms
# Speed: 2.0ms preprocess, 26.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 3 motorcycles, 3 trucks, 26.3ms
# Speed: 2.0ms preprocess, 26.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 3 motorcycles, 3 trucks, 25.8ms
# Speed: 3.0ms preprocess, 25.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 4 motorcycles, 1 truck, 26.5ms
# Speed: 1.1ms preprocess, 26.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 5 motorcycles, 2 trucks, 1 handbag, 26.2ms
# Speed: 2.0ms preprocess, 26.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 4 motorcycles, 2 trucks, 1 handbag, 25.6ms
# Speed: 4.2ms preprocess, 25.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 4 motorcycles, 2 trucks, 26.5ms
# Speed: 1.8ms preprocess, 26.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 3 motorcycles, 2 trucks, 26.3ms
# Speed: 1.0ms preprocess, 26.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 4 motorcycles, 2 trucks, 26.7ms
# Speed: 1.0ms preprocess, 26.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 4 motorcycles, 2 trucks, 25.9ms
# Speed: 2.0ms preprocess, 25.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 4 motorcycles, 2 trucks, 25.4ms
# Speed: 2.0ms preprocess, 25.4ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 6 motorcycles, 2 trucks, 1 horse, 26.3ms
# Speed: 2.0ms preprocess, 26.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 5 motorcycles, 2 trucks, 26.4ms
# Speed: 2.0ms preprocess, 26.4ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 3 motorcycles, 1 cow, 25.9ms
# Speed: 1.0ms preprocess, 25.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 3 motorcycles, 2 trucks, 25.9ms
# Speed: 2.0ms preprocess, 25.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 4 motorcycles, 2 trucks, 1 umbrella, 25.1ms
# Speed: 2.0ms preprocess, 25.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 5 motorcycles, 2 trucks, 26.6ms
# Speed: 2.0ms preprocess, 26.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 7 motorcycles, 2 trucks, 1 umbrella, 25.7ms
# Speed: 2.0ms preprocess, 25.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 bicycle, 5 motorcycles, 1 truck, 26.1ms
# Speed: 2.0ms preprocess, 26.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 7 motorcycles, 2 trucks, 1 umbrella, 26.0ms
# Speed: 2.0ms preprocess, 26.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 4 motorcycles, 2 trucks, 25.5ms
# Speed: 2.0ms preprocess, 25.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 8 motorcycles, 2 trucks, 26.0ms
# Speed: 2.0ms preprocess, 26.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 5 motorcycles, 2 trucks, 26.6ms
# Speed: 2.0ms preprocess, 26.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 4 motorcycles, 2 trucks, 27.0ms
# Speed: 1.0ms preprocess, 27.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 7 motorcycles, 2 trucks, 26.3ms
# Speed: 2.0ms preprocess, 26.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 6 motorcycles, 1 truck, 25.8ms
# ...
# Speed: 2.0ms preprocess, 25.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 motorcycle, 2 buss, 1 truck, 26.3ms
# Speed: 2.2ms preprocess, 26.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 motorcycle, 2 buss, 25.4ms
# Speed: 2.0ms preprocess, 25.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 motorcycle, 2 buss, 2 trucks, 25.6ms
# Speed: 1.7ms preprocess, 25.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 motorcycle, 2 buss, 1 truck, 26.3ms
# Speed: 2.2ms preprocess, 26.3ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 motorcycle, 2 buss, 26.7ms
# Speed: 1.0ms preprocess, 26.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 motorcycle, 3 buss, 25.6ms
# Speed: 4.8ms preprocess, 25.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 bicycle, 1 motorcycle, 5 buss, 26.5ms
# Speed: 2.0ms preprocess, 26.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 bicycle, 1 motorcycle, 3 buss, 25.6ms
# Speed: 2.5ms preprocess, 25.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 bicycle, 1 motorcycle, 2 buss, 1 truck, 25.9ms
# Speed: 5.5ms preprocess, 25.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 motorcycle, 2 buss, 1 truck, 29.5ms
# Speed: 0.0ms preprocess, 29.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 motorcycle, 2 buss, 26.3ms
# Speed: 2.0ms preprocess, 26.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 motorcycle, 4 buss, 26.0ms
# Speed: 1.0ms preprocess, 26.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 bicycle, 2 motorcycles, 2 buss, 25.4ms
# Speed: 2.0ms preprocess, 25.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 bicycle, 1 motorcycle, 2 buss, 25.7ms
# Speed: 3.0ms preprocess, 25.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 4 buss, 25.6ms
# Speed: 2.0ms preprocess, 25.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 motorcycle, 5 buss, 26.4ms
# Speed: 1.0ms preprocess, 26.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 motorcycle, 4 buss, 1 boat, 26.7ms
# Speed: 4.2ms preprocess, 26.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 motorcycle, 3 buss, 1 boat, 29.5ms
# Speed: 0.0ms preprocess, 29.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 motorcycle, 4 buss, 1 train, 1 truck, 1 boat, 26.7ms
# Speed: 2.0ms preprocess, 26.7ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 motorcycle, 3 buss, 1 truck, 26.9ms
# Speed: 1.0ms preprocess, 26.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 motorcycle, 3 buss, 1 train, 1 truck, 26.3ms
# Speed: 9.6ms preprocess, 26.3ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 motorcycle, 2 buss, 1 train, 26.8ms
# Speed: 1.5ms preprocess, 26.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 motorcycle, 2 buss, 1 train, 26.8ms
# Speed: 2.1ms preprocess, 26.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 motorcycle, 4 buss, 1 train, 1 boat, 29.9ms
# Speed: 0.0ms preprocess, 29.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 car, 1 motorcycle, 4 buss, 1 train, 26.0ms
# Speed: 2.0ms preprocess, 26.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 1 motorcycle, 2 buss, 1 train, 26.7ms
# Speed: 2.0ms preprocess, 26.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 car, 1 motorcycle, 2 buss, 1 train, 25.8ms
# Speed: 2.0ms preprocess, 25.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 2 cars, 1 motorcycle, 1 bus, 25.9ms
# Speed: 2.4ms preprocess, 25.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 car, 1 motorcycle, 1 bus, 27.4ms
# Speed: 0.0ms preprocess, 27.4ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 motorcycle, 1 bus, 25.1ms
# Speed: 3.7ms preprocess, 25.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 motorcycle, 3 buss, 26.6ms
# Speed: 3.6ms preprocess, 26.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 motorcycle, 2 buss, 1 truck, 26.0ms
# Speed: 1.2ms preprocess, 26.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 motorcycle, 3 buss, 1 truck, 25.8ms
# Speed: 1.0ms preprocess, 25.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 car, 1 motorcycle, 1 bus, 2 trucks, 26.3ms
# Speed: 1.5ms preprocess, 26.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 car, 1 motorcycle, 2 buss, 2 trucks, 25.7ms
# Speed: 1.0ms preprocess, 25.7ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 car, 1 motorcycle, 2 buss, 1 truck, 26.3ms
# Speed: 1.0ms preprocess, 26.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 motorcycle, 2 buss, 2 trucks, 26.3ms
# Speed: 1.0ms preprocess, 26.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 motorcycle, 3 buss, 26.0ms
# Speed: 2.0ms preprocess, 26.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 motorcycle, 3 buss, 25.8ms
# Speed: 2.0ms preprocess, 25.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 motorcycle, 3 buss, 1 bird, 26.7ms
# Speed: 2.0ms preprocess, 26.7ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 motorcycle, 3 buss, 2 trucks, 1 bird, 26.1ms
# Speed: 1.8ms preprocess, 26.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 motorcycle, 3 buss, 2 trucks, 25.8ms
# Speed: 1.0ms preprocess, 25.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 motorcycle, 3 buss, 1 truck, 28.2ms
# Speed: 0.0ms preprocess, 28.2ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 2 motorcycles, 2 buss, 2 trucks, 25.9ms
# Speed: 4.1ms preprocess, 25.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 motorcycle, 1 bus, 2 trucks, 26.0ms
# Speed: 2.4ms preprocess, 26.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 motorcycles, 2 buss, 2 trucks, 26.1ms
# Speed: 1.5ms preprocess, 26.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 motorcycle, 1 bus, 3 trucks, 26.3ms
# Speed: 2.0ms preprocess, 26.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 motorcycles, 3 buss, 1 truck, 1 bird, 25.8ms
# Speed: 2.0ms preprocess, 25.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 2 motorcycles, 2 buss, 2 trucks, 1 bird, 25.9ms
# Speed: 1.3ms preprocess, 25.9ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 2 motorcycles, 2 buss, 3 trucks, 25.9ms
# Speed: 2.0ms preprocess, 25.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 motorcycle, 2 buss, 2 trucks, 26.1ms
# Speed: 2.0ms preprocess, 26.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 motorcycles, 2 buss, 26.0ms
# Speed: 1.6ms preprocess, 26.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 3 motorcycles, 2 buss, 1 truck, 1 handbag, 25.6ms
# Speed: 2.3ms preprocess, 25.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 motorcycle, 2 buss, 2 trucks, 2 handbags, 27.2ms
# Speed: 1.0ms preprocess, 27.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 motorcycles, 2 buss, 2 trucks, 27.3ms
# Speed: 2.0ms preprocess, 27.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 motorcycles, 2 buss, 2 trucks, 26.6ms
# Speed: 2.0ms preprocess, 26.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 motorcycles, 1 bus, 2 trucks, 1 handbag, 26.3ms
# Speed: 2.0ms preprocess, 26.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 2 motorcycles, 1 bus, 2 trucks, 2 handbags, 25.8ms
# Speed: 2.0ms preprocess, 25.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 motorcycles, 1 bus, 2 trucks, 26.5ms
# Speed: 1.9ms preprocess, 26.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 2 motorcycles, 2 buss, 2 trucks, 26.5ms
# Speed: 3.0ms preprocess, 26.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 2 motorcycles, 2 buss, 2 trucks, 25.9ms
# Speed: 2.0ms preprocess, 25.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 2 motorcycles, 2 buss, 1 truck, 2 handbags, 26.4ms
# Speed: 1.2ms preprocess, 26.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 2 motorcycles, 2 buss, 1 truck, 26.1ms
# Speed: 2.0ms preprocess, 26.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 2 motorcycles, 2 buss, 2 trucks, 25.8ms
# Speed: 2.0ms preprocess, 25.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 2 motorcycles, 1 bus, 2 trucks, 26.1ms
# Speed: 2.2ms preprocess, 26.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 2 motorcycles, 1 bus, 2 trucks, 26.0ms
# Speed: 2.0ms preprocess, 26.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 2 motorcycles, 2 buss, 2 trucks, 29.8ms
# Speed: 0.0ms preprocess, 29.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 motorcycle, 2 buss, 1 truck, 25.9ms
# Speed: 2.0ms preprocess, 25.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 2 motorcycles, 2 buss, 2 trucks, 26.3ms
# Speed: 2.0ms preprocess, 26.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 2 motorcycles, 1 bus, 2 trucks, 26.7ms
# Speed: 1.0ms preprocess, 26.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 2 motorcycles, 2 buss, 2 trucks, 25.8ms
# Speed: 1.0ms preprocess, 25.8ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 bicycle, 2 motorcycles, 2 buss, 1 truck, 25.5ms
# Speed: 2.0ms preprocess, 25.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 bicycle, 2 motorcycles, 2 buss, 1 truck, 25.2ms
# Speed: 2.1ms preprocess, 25.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 2 motorcycles, 2 buss, 1 truck, 26.0ms
# Speed: 2.0ms preprocess, 26.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 2 motorcycles, 2 buss, 1 truck, 26.1ms
# Speed: 2.1ms preprocess, 26.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 motorcycle, 2 buss, 2 trucks, 26.3ms
# Speed: 3.1ms preprocess, 26.3ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 motorcycle, 2 buss, 2 trucks, 26.3ms
# Speed: 2.0ms preprocess, 26.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 motorcycle, 2 buss, 2 trucks, 26.6ms
# Speed: 1.0ms preprocess, 26.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 motorcycle, 1 bus, 2 trucks, 25.4ms
# Speed: 3.0ms preprocess, 25.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 motorcycle, 1 bus, 2 trucks, 25.8ms
# Speed: 1.9ms preprocess, 25.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 bicycle, 1 bus, 2 trucks, 29.4ms
# Speed: 0.0ms preprocess, 29.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 motorcycle, 2 buss, 1 truck, 26.4ms
# Speed: 2.0ms preprocess, 26.4ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 bicycle, 2 buss, 1 truck, 27.0ms
# Speed: 2.0ms preprocess, 27.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 motorcycle, 1 bus, 1 truck, 25.8ms
# Speed: 2.0ms preprocess, 25.8ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 3 motorcycles, 2 buss, 1 truck, 26.1ms
# Speed: 2.0ms preprocess, 26.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 2 motorcycles, 2 buss, 2 trucks, 28.0ms
# Speed: 0.0ms preprocess, 28.0ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 2 motorcycles, 2 buss, 2 trucks, 26.6ms
# Speed: 2.0ms preprocess, 26.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 2 motorcycles, 2 buss, 1 truck, 26.7ms
# Speed: 1.8ms preprocess, 26.7ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 motorcycle, 2 buss, 2 trucks, 25.9ms
# Speed: 4.0ms preprocess, 25.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 bicycle, 1 motorcycle, 2 buss, 2 trucks, 26.7ms
# Speed: 1.0ms preprocess, 26.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 3 motorcycles, 2 buss, 1 truck, 26.7ms
# Speed: 1.0ms preprocess, 26.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 3 motorcycles, 2 buss, 1 truck, 26.1ms
# Speed: 2.0ms preprocess, 26.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 bicycle, 2 motorcycles, 1 bus, 1 truck, 25.2ms
# Speed: 2.3ms preprocess, 25.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 bicycle, 1 bus, 2 trucks, 26.5ms
# Speed: 2.0ms preprocess, 26.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 bicycle, 1 motorcycle, 1 bus, 1 truck, 26.8ms
# Speed: 1.0ms preprocess, 26.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 bicycle, 1 motorcycle, 1 bus, 1 truck, 1 handbag, 26.3ms
# Speed: 2.0ms preprocess, 26.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 motorcycle, 1 bus, 1 truck, 1 handbag, 25.3ms
# Speed: 2.0ms preprocess, 25.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 motorcycle, 1 bus, 1 truck, 1 handbag, 26.7ms
# Speed: 1.2ms preprocess, 26.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 motorcycle, 1 bus, 1 handbag, 26.0ms
# Speed: 2.3ms preprocess, 26.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Average FPS: 27.652
